# %% [markdown]
# What is the difference between hardware and software? Give one example of each
#
# Hardeware is the physical componenets of the computer ,example CPU
# Software is the programing language used to run the computer hardware
# example : windows
